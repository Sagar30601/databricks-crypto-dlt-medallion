-- %%
SELECT *
FROM read_files(
  '/Volumes/crypto_analytics/landing/raw/csv/BTCUSDT_daily.csv',
  format => 'csv',
  header => true,
  skipRows => 1
);

-- %%
SELECT *
FROM read_files(
  '/Volumes/crypto_analytics/landing/raw/csv/ADAUSDT_daily.csv',
  format => 'csv',
  header => true,
  skipRows => 1
);

-- %%
-- Daily Market Summary
CREATE VIEW IF NOT EXISTS crypto_analytics.gold.daily_market_summary
AS SELECT * FROM crypto_analytics.silver.daily_market_summary;

-- Coin Volatility
CREATE VIEW IF NOT EXISTS crypto_analytics.gold.coin_volatility
AS SELECT * FROM crypto_analytics.silver.coin_volatility;

-- Top Performers Monthly
CREATE VIEW IF NOT EXISTS crypto_analytics.gold.top_performers_monthly
AS SELECT * FROM crypto_analytics.silver.top_performers_monthly;

-- Market Cap Dominance
CREATE VIEW IF NOT EXISTS crypto_analytics.gold.market_cap_dominance
AS SELECT * FROM crypto_analytics.silver.market_cap_dominance;

-- %%
-- Raw OHLCV CSV
CREATE VIEW IF NOT EXISTS crypto_analytics.bronze.raw_ohlcv_csv
AS SELECT * FROM crypto_analytics.silver.raw_ohlcv_csv;

-- Raw OHLCV API
CREATE VIEW IF NOT EXISTS crypto_analytics.bronze.raw_ohlcv_api
AS SELECT * FROM crypto_analytics.silver.raw_ohlcv_api;

-- Raw Market Cap
CREATE VIEW IF NOT EXISTS crypto_analytics.bronze.raw_market_cap
AS SELECT * FROM crypto_analytics.silver.raw_market_cap;
